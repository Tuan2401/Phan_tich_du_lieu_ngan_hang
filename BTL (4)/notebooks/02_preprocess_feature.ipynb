# %%
import pandas as pd
import numpy as np
import os

print("🚀 Load data...")

data = pd.read_csv("../data/raw/bank.csv", sep=";")

# chuẩn hóa cột
data.columns = data.columns.str.strip().str.lower()

print("📊 Columns:", data.columns)

# =====================
# CLEAN DATA
# =====================
data.replace("unknown", np.nan, inplace=True)
data.dropna(inplace=True)

# =====================
# FEATURE
# =====================
if 'y' in data.columns:
    data['y'] = data['y'].map({'yes':1, 'no':0})
else:
    print("❌ Không có cột y")

data["balance_log"] = np.log1p(data["balance"].clip(lower=0))

# =====================
# SAVE
# =====================
os.makedirs("../data/processed", exist_ok=True)
data.to_csv("../data/processed/data_processed.csv", index=False)

print("✅ DONE")
# Out:
# 🚀 Load data...
# 📊 Columns: Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='str')
# ✅ DONE
